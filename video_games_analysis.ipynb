# %% [markdown]
# ## EXPLORATORY ANALYSIS ON VIDEO GAMES AROUND THE WORLD
#
# This dataset contains a list of video games with sales greater than 100,000 copies.
#
# Rank - Ranking of overall sales.
#
# Name - The games name.
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.).
#
# Year - Year of the game's release.
#
# Genre - Genre of the game.
#
# Publisher - Publisher of the game.
#
# NA_Sales - Sales in North America (in millions).
#
# EU_Sales - Sales in Europe (in millions).
#
# JP_Sales - Sales in Japan (in millions).
#
# Other_Sales - Sales in the rest of the world (in millions).
#
# Global_Sales - Total worldwide sales.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
#Observing the first few rows of our dataset
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
#checking shape of data
df.shape
# Out:
# (16719, 16)

# %%
# checking data types
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0              76.0          51.0         8.0       322.0  Nintendo      E
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      E
# 3              80.0          73.0         8.0       192.0  Nintendo      E
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
# checking missing values
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Deleting multiple columns
df.drop(['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# checking missing values (rows)
df.loc[df['Genre'].isnull()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 659        0.53      0.00         0.08          2.39
# 14246      0.00      0.03         0.00          0.03

# %%
df.loc[df['Name'].isnull()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 659        0.53      0.00         0.08          2.39
# 14246      0.00      0.03         0.00          0.03

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# renaming Year_of_Release to Release-Year
df = df.rename(columns = {'Year_of_Release' : 'Release_Year'})

# %%
df.Release_Year
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16714    2016.0
# 16715    2006.0
# 16716    2016.0
# 16717    2003.0
# 16718    2016.0
# Name: Release_Year, Length: 16719, dtype: float64

# %%
#Changing year format
df['Release_Year'] = [int(i) for i in df['Release_Year']]

# %%
# to check if there are other rows with same platform, release_year and publisher to get the name and genre of missing rows
df.loc[(df['Platform'] == 'GEN') & (df['Release_Year'] == 1993) & (df['Publisher'] == 'Acclaim Entertainment')]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Release_Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %% [markdown]
# we observed that there are no other rows with similar info so we decide to drop the rows

# %%
# deleting missing rows
df.dropna(inplace = True)

# %%
# confirming if values are dropped
df.isnull().sum()
# Out:
# Name            0
# Platform        0
# Release_Year    0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
# descriptive statistics overview
df.describe()
# Out:
#        Release_Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16416.000000  16416.000000  16416.000000  16416.000000  16416.000000
# mean    2006.489888      0.264129      0.146034      0.078623      0.047670
# std        5.881148      0.819028      0.507134      0.311348      0.188156
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.030000
# max     2020.000000     41.360000     28.960000     10.220000     10.570000
#
#        Global_Sales
# count  16416.000000
# mean       0.536708
# std        1.559885
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.530000

# %% [markdown]
# The line plot above shows the total game sold from 1980 to 2020 in North America and we can see the rise in sales started after 1995 , the maximum sales generated occured in 2009. However, the sales starts to drop continiously from 2010.

# %%
#checking for the Genre with the highest number in the data frame
df.Genre.value_counts()
# Out:
# Action          3307
# Sports          2306
# Misc            1697
# Role-Playing    1483
# Shooter         1296
# Adventure       1291
# Racing          1225
# Platform         878
# Simulation       855
# Fighting         837
# Strategy         672
# Puzzle           569
# Name: Genre, dtype: int64

# %%
# visualizing the total sales  trend between 1980 to 2020 in North America
fig, ax = plt.subplots(figsize=(20, 8))
yearly_sales = df.groupby("Release_Year", as_index = False)["NA_Sales"].sum()
sns.lineplot(yearly_sales["Release_Year"], yearly_sales["NA_Sales"], marker = "o", color="y")
# Out:
# <AxesSubplot:xlabel='Release_Year', ylabel='NA_Sales'>

# %% [markdown]
# It is observed that Action Genre has highest number of users.

# %%
# visualizing the total sales  trend between 1980 to 2020 in Europe
fig, ax = plt.subplots(figsize=(20, 8))
yearly_sales = df.groupby("Release_Year", as_index = False)["EU_Sales"].sum()
sns.lineplot(yearly_sales["Release_Year"], yearly_sales["EU_Sales"], marker = "o")
# Out:
# <AxesSubplot:xlabel='Release_Year', ylabel='EU_Sales'>

# %% [markdown]
# The above graph shows the same trend as in the North America with the peak year was also 2009, the rise also start from 1995 as well while the drop contines to steep from 2010.

# %%
# visualizing the total sales  trend between 1980 to 2020 in Japan
fig, ax = plt.subplots(figsize=(20, 8))
yearly_sales = df.groupby("Release_Year", as_index = False)["JP_Sales"].sum()
sns.lineplot(yearly_sales["Release_Year"], yearly_sales["JP_Sales"], marker = "o", color="r")
# Out:
# <AxesSubplot:xlabel='Release_Year', ylabel='JP_Sales'>

# %% [markdown]
# This line plot differs from the North america and the Europe, video games sales has been showing increase in revenues from 1983 up to 1996, however the sales falls for 7 years befor starting to grow massively from 2004 to 2006 which recoreded the highes salesin japan before dropping low till 2020.

# %%
# visualizing the total sales  trend between 1980 to 2020 in Other countries combined
fig, ax = plt.subplots(figsize=(20, 8))
yearly_sales = df.groupby("Release_Year", as_index = False)["Other_Sales"].sum()
sns.lineplot(yearly_sales["Release_Year"], yearly_sales["Other_Sales"], marker = "o", color="g")
# Out:
# <AxesSubplot:xlabel='Release_Year', ylabel='Other_Sales'>

# %% [markdown]
# The year with the highest peak occured in 2008, the sales from 1980 to 1995 seems to be uniform untill 1996 when it begin to rise.

# %%
#checking the publisher with the highest video games sales 
publisher = df.groupby("Publisher")["Global_Sales"].sum().reset_index()
publisher = publisher.sort_values("Global_Sales", ascending = False).head(10)

# %%
fig, ax = plt.subplots(figsize=(25, 8))
sns.barplot(data = publisher, x = "Publisher", y = "Global_Sales")
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='Global_Sales'>

# %% [markdown]
# Above barplot shows the top 10 game publishers with the highhest global revenue, Nintendo recouped $1,750,000,000.

# %%
#checking the video game sales variability in all regions to visualize how spread out the sales.
region = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]

for i in region:
    fig, ax = plt.subplots(figsize=(18, 8))
    sns.scatterplot(data = df, x = "Genre", y = i)

# %% [markdown]
# The variablity visualization above makes it evident on how the sales in all regions varies from one another , which confirm again that the North America sales has the highest standard of deviation with other countries sales being least.

# %%
total_sales = df.groupby("Genre", as_index = False)[["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"]].sum()

# %%
total_sales
# Out:
#            Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         Action    863.17    510.99    160.14       182.22       1717.62
# 1      Adventure    101.39     63.15     52.22        16.37        233.25
# 2       Fighting    220.51     99.00     87.28        35.87        442.63
# 3           Misc    394.01    208.55    107.02        73.00        783.19
# 4       Platform    444.44    199.39    130.71        51.01        825.86
# 5         Puzzle    121.13     49.78     56.68        12.30        240.33
# 6         Racing    356.86    234.48     56.63        75.51        723.69
# 7   Role-Playing    330.04    188.24    353.44        59.41        930.90
# 8        Shooter    584.83    314.52     38.68       103.33       1041.83
# 9     Simulation    180.67    113.17     63.64        30.59        388.22
# 10        Sports    671.20    371.33    134.93       132.21       1310.39
# 11      Strategy     67.69     44.69     49.30        10.73        172.69

# %% [markdown]
# Above Dataframe highlights the total sales of each Genre in North America, Europe, Japan,
# Other countries and the total global sales of each Genre, with all numbers represented in millions.

# %%
# Graphical representation of the total sales of each region
fig, ax = plt.subplots(figsize=(25, 8))
sns.barplot(data=total_sales, x = "Genre", y = "NA_Sales")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='NA_Sales'>

# %%
fig, ax = plt.subplots(figsize=(25, 8))
sns.barplot(data=total_sales, x = "Genre", y = "EU_Sales")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='EU_Sales'>

# %%
fig, ax = plt.subplots(figsize=(25, 8))
sns.barplot(data=total_sales, x = "Genre", y = "JP_Sales")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='JP_Sales'>

# %%
fig, ax = plt.subplots(figsize=(25, 8))
sns.barplot(data=total_sales, x = "Genre", y = "Other_Sales")
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Other_Sales'>

# %% [markdown]
# The bar plots above shows Action and sports genre games are the most dominant in terms of revenue in the world except for japan whose Role-playing genre has the highest revenue.

# %%
#the overall video game sales among Genre.
plt.pie(total_sales.Global_Sales, labels = total_sales.Genre, radius = 2, autopct = "%0.0f%%")
plt.show()

# %% [markdown]
# The pie chart above shows that Action, Sports and shooter video games are the top 3 Genre with the biggest global sales, taking a whooping 47% of the entire global sales. While Strategy, Puzzle and Adventure occupy the bottom three.
#
# CONCLUSION:
# Action games are the most popular Game genre around the world with a total global sales of a little over 1.7 billion. Sport Genre is the second both in popularity and sales recorded globally with a little over 1.3 billion. However, Strategy Genre is the least in popularity and with the lowest global sales of just 173 million. After the exploration of this Dataset, its evident that Action, Sport and Shooter video game genres are the proposed genres for individual looking to invest in the video games industry in any part of the word except for Japan whose the ideal genre would be Role-Playing.
