# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
#checking shape of data
df.shape
# Out:
# (16719, 16)

# %%
# checking data types
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# checking missing values
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Deleting multiple columns
df.drop(['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# checking missing values (rows)
df.loc[df['Genre'].isnull()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 659        0.53      0.00         0.08          2.39
# 14246      0.00      0.03         0.00          0.03

# %%
df.loc[df['Name'].isnull()]
# Out:
#       Name Platform  Year_of_Release Genre              Publisher  NA_Sales  \
# 659    NaN      GEN           1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN           1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 659        0.53      0.00         0.08          2.39
# 14246      0.00      0.03         0.00          0.03

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# renaming Year_of_Release to Release-Year
df = df.rename(columns = {'Year_of_Release' : 'Release_Year'})

# %%
# to check if there are other rows with same platform, release_year and publisher to get the name and genre
df.loc[(df['Platform'] == 'GEN') & (df['Release_Year'] == 1993) & (df['Publisher'] == 'Acclaim Entertainment')]
# Out:
#       Name Platform  Release_Year Genre              Publisher  NA_Sales  \
# 659    NaN      GEN        1993.0   NaN  Acclaim Entertainment      1.78
# 14246  NaN      GEN        1993.0   NaN  Acclaim Entertainment      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 659        0.53      0.00         0.08          2.39
# 14246      0.00      0.03         0.00          0.03

# %% [markdown]
# we observed that there are no other rows with similar info so we decide to drop the rows

# %%
# deleting missing rows
df.dropna(inplace = True)

# %%
# confirming if values are dropped
df.isnull().sum()
# Out:
# Name            0
# Platform        0
# Release_Year    0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
# descriptive statistics overview
df.describe()
# Out:
#        Release_Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16416.000000  16416.000000  16416.000000  16416.000000  16416.000000
# mean    2006.489888      0.264129      0.146034      0.078623      0.047670
# std        5.881148      0.819028      0.507134      0.311348      0.188156
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.030000
# max     2020.000000     41.360000     28.960000     10.220000     10.570000
#
#        Global_Sales
# count  16416.000000
# mean       0.536708
# std        1.559885
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.530000

# %%
#checking for the Genre with the highest number in the data frame
df.Genre.value_counts()
# Out:
# Action          3307
# Sports          2306
# Misc            1697
# Role-Playing    1483
# Shooter         1296
# Adventure       1291
# Racing          1225
# Platform         878
# Simulation       855
# Fighting         837
# Strategy         672
# Puzzle           569
# Name: Genre, dtype: int64

# %%
# It is observed that Action Genre has highest number of users.

# %%
df
# Out:
#                                 Name Platform  Release_Year         Genre  \
# 0                         Wii Sports      Wii        2006.0        Sports
# 1                  Super Mario Bros.      NES        1985.0      Platform
# 2                     Mario Kart Wii      Wii        2008.0        Racing
# 3                  Wii Sports Resort      Wii        2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       G
simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.groupby("Publisher")["EU_Sales", "NA_Sales", "JP_Sales"].sum().reset_index().sort_values("JP_Sales", ascending= False).head(10)
# Out:
#                         Publisher  EU_Sales  NA_Sales  JP_Sales
# 361                      Nintendo    419.01    816.97    458.15
# 349            Namco Bandai Games     42.16     69.90    127.85
# 277  Konami Digital Entertainment     68.98     91.90     91.40
# 458   Sony Computer Entertainment    186.56    266.17     74.15
# 85                         Capcom     38.53     78.25     68.43
# 448                          Sega     80.66    108.61     57.06
# 468                   Square Enix     32.41     48.29     50.09
# 470                    SquareSoft      4.95     11.06     40.13
# 145              Enix Corporation      0.31      0.76     32.40
# 504                    Tecmo Koei      6.78     14.08     29.47

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
df.head()
# Out:
#                        Name Platform  Release_Year         Genre Publisher  \
# 0                Wii Sports      Wii          2006        Sports  Nintendo
# 1         Super Mario Bros.      NES          1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii          2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii          2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB          1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.36     28.96      3.77         8.45         82.53
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# grouping the mean of "EU_Sales" by"Name" and sorting in descending order
df.groupby('Name').JP_Sales.mean().reset_index().sort_values("JP_Sales", ascending = False).head()
# Out:
#                                Name  JP_Sales
# 7294       Pokemon Red/Pokemon Blue     10.22
# 7281    Pokemon Gold/Pokemon Silver      7.20
# 6677          New Super Mario Bros.      6.50
# 7279  Pokemon Diamond/Pokemon Pearl      6.04
# 7273    Pokemon Black/Pokemon White      5.65

# %%
df.groupby(['Name', 'Platform'])['NA_Sales'].mean().reset_index().head()
# Out:
#                           Name Platform  NA_Sales
# 0               Beyblade Burst      3DS      0.00
# 1            Fire Emblem Fates      3DS      0.81
# 2         Frozen: Olaf's Quest      3DS      0.27
# 3         Frozen: Olaf's Quest       DS      0.21
# 4   Haikyu!! Cross Team Match!      3DS      0.00

# %%
df.groupby(['Name', 'Platform', 'Genre'])['EU_Sales'].mean().reset_index().head()
# Out:
#                           Name Platform         Genre  EU_Sales
# 0               Beyblade Burst      3DS  Role-Playing      0.00
# 1            Fire Emblem Fates      3DS  Role-Playing      0.23
# 2         Frozen: Olaf's Quest      3DS      Platform      0.27
# 3         Frozen: Olaf's Quest       DS      Platform      0.26
# 4   Haikyu!! Cross Team Match!      3DS     Adventure      0.00

# %%
address()
# Out:
# alexander platz

# %%
def address(home_address):
    print("my home address is", home_address)

# %%
address("fontane str")
# Out:
# my home address is fontane str

# %%
def address():
    return "my home address is ALEXANDER PLATZ"

address()
# Out:
# 'my home address is ALEXANDER PLATZ'

# %%
new_variable = address()

# %%
new_variable
# Out:
# 'my home address is ALEXANDER PLATZ'

# %%
def age():
    pappy_age = 12
    return pappy_age
age()
# Out:
# 12

# %%
real_age = age()

# %%
summ = real_age + 10

# %%
summ
# Out:
# 22
